# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\ML-Projects\loan_data.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       381.000000         381.000000  381.000000        370.000000
# mean       3579.845144        1277.275381  104.986877        340.864865
# std        1419.813818        2340.818114   28.358464         68.549257
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2600.000000           0.000000   90.000000        360.000000
# 50%        3333.000000         983.000000  110.000000        360.000000
# 75%        4288.000000        2016.000000  127.000000        360.000000
# max        9703.000000       33837.000000  150.000000        480.000000
#
#        Credit_History
# count      351.000000
# mean         0.837607
# std          0.369338
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.nunique()
# Out:
# Loan_ID              381
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      322
# CoapplicantIncome    182
# LoanAmount           101
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
df['Dependents'].unique()
# Out:
# array(['1', '0', '2', '3+', nan], dtype=object)

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  84.,  12.,  36.])

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Store rows where 'self employed' is null
null_self_employed_rows = df[df['Self_Employed'].isna()]

# %%
 new=null_self_employed_rows.groupby('Self_Employed')['Loan_Status'].value_counts()

# %%
null_self_employed_rows
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 6    LP001027    Male     Yes          2      Graduate           NaN
# 13   LP001041    Male     Yes          0      Graduate           NaN
# 20   LP001087  Female      No          2      Graduate           NaN
# 72   LP001370    Male      No          0  Not Graduate           NaN
# 75   LP001387  Female     Yes          0      Graduate           NaN
# 76   LP001398    Male      No          0      Graduate           NaN
# 96   LP001546    Male      No          0      Graduate           NaN
# 103  LP001581    Male     Yes          0  Not Graduate           NaN
# 134  LP001732    Male     Yes          2      Graduate           NaN
# 142  LP001768    Male     Yes          0      Graduate           NaN
# 166  LP001883  Female      No          0      Graduate           NaN
# 186  LP001949    Male     Yes         3+      Graduate           NaN
# 217  LP002128    Male     Yes          2      Graduate           NaN
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            381 non-null    object
#  1   Gender             376 non-null    object
#  2   Married            381 non-null    object
#  3   Dependents         373 non-null    object
#  4   Education          381 non-null    object
#  5   Self_Employed      360 non-null    object
#  6   ApplicantIncome    381 non-null    int64
#  7   CoapplicantIncome  381 non-null    float64
#  8   LoanAmount         381 non-null    float64
#  9   Loan_Amount_Term   370 non-null    float64
#  10  Credit_History     351 non-null    float64
#  11  Property_Area      381 non-null    object
#  12  Loan_Status        381 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 38.8+ KB

# %%
df.dropna(inplace=True)

# %%
sns.histplot(data=df['ApplicantIncome'],kde = True,color='cyan')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
sns.countplot(data=df,x='Loan_Status')
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
df.groupby('Education')['LoanAmount'].mean().reset_index()
# Out:
#       Education  LoanAmount
# 0      Graduate  105.344978
# 1  Not Graduate  102.531646

# %%
avg_loanamount=df.groupby('Education')['LoanAmount'].mean().reset_index()

# %%
avg_loanamount
# Out:
#       Education  LoanAmount
# 0      Graduate  105.344978
# 1  Not Graduate  102.531646

# %%
sns.barplot(x='Education',y ='LoanAmount',data = avg_loanamount)
# Out:
# <Axes: xlabel='Education', ylabel='LoanAmount'>

# %%
# Create a grouped count of education and loan status
grouped_data = df.groupby(['Education', 'Loan_Status']).size().unstack()

# Plot as a bar chart
grouped_data.plot(kind='bar', figsize=(8, 6), colormap='Set2')

plt.title('Loan Approval Status by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Number of Applicants')
plt.legend(title='Loan Status', labels=['Not Approved', 'Approved'])
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x="Property_Area",y='LoanAmount',data=df)
# Out:
# <Axes: xlabel='Property_Area', ylabel='LoanAmount'>

# %%
sns.countplot(x='Loan_Status',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
 df['Gender'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
loan_status_married = df.groupby(['Married','Loan_Status']).size().unstack()

# %%
loan_status_married.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Married'>

# %%
sns.scatterplot(x='ApplicantIncome',y='LoanAmount',data=df)
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
heatmap=df.select_dtypes(include=['int64','float64'])

# %%
corr=heatmap.corr()

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Credit_History'].unique()
# Out:
# array([1., 0.])

# %%
residence=df.groupby(['Property_Area','Loan_Status']).size().unstack()

# %%
residence.plot(kind='bar', figsize=(8, 6), colormap='Set2')
plt.title('Area')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
X=df[['Married','Education','ApplicantIncome','LoanAmount','Credit_History']]

# %%
X
# Out:
#     Married     Education  ApplicantIncome  LoanAmount  Credit_History
# 0       Yes      Graduate             4583       128.0             1.0
# 1       Yes      Graduate             3000        66.0             1.0
# 2       Yes  Not Graduate             2583       120.0             1.0
# 3        No      Graduate             6000       141.0             1.0
# 4       Yes  Not Graduate             2333        95.0             1.0
# ..      ...           ...              ...         ...             ...
# 376     Yes      Graduate             5703       128.0             1.0
# 377     Yes      Graduate             3232       108.0             1.0
# 378      No      Graduate             2900        71.0             1.0
# 379     Yes      Graduate             4106        40.0             1.0
# 380      No      Graduate             4583       133.0             0.0
#
# [308 rows x 5 columns]

# %%
Y = df[['Loan_Status']]

# %%
Y
# Out:
#     Loan_Status
# 0             N
# 1             Y
# 2             Y
# 3             Y
# 4             Y
# ..          ...
# 376           Y
# 377           Y
# 378           Y
# 379           Y
# 380           N
#
# [308 rows x 1 columns]

# %%
from sklearn import preprocessing
lb = preprocessing.LabelEncoder()
import warnings
warnings.filterwarnings('ignore')

# %%
Y['Loan_Status']=lb.fit_transform(Y['Loan_Status'])

# %%
Y
# Out:
#      Loan_Status
# 0              0
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 376            1
# 377            1
# 378            1
# 379            1
# 380            0
#
# [308 rows x 1 columns]

# %%
X['Education']=lb.fit_transform(X['Education'])

# %%
X['Married']=lb.fit_transform(X['Married'])

# %%
X
# Out:
#      Married  Education  ApplicantIncome  LoanAmount  Credit_History
# 0          1          0             4583       128.0             1.0
# 1          1          0             3000        66.0             1.0
# 2          1          1             2583       120.0             1.0
# 3          0          0             6000       141.0             1.0
# 4          1          1             2333        95.0             1.0
# ..       ...        ...              ...         ...             ...
# 376        1          0             5703       128.0             1.0
# 377        1          0             3232       108.0             1.0
# 378        0          0             2900        71.0             1.0
# 379        1          0             4106        40.0             1.0
# 380        0          0             4583       133.0             0.0
#
# [308 rows x 5 columns]

# %%
X['Credit_History'][0]
# Out:
# np.float64(1.0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X=scaler.fit_transform(X)

# %%
X
# Out:
# array([[ 0.81539246, -0.58734842,  0.67389339,  0.79689813,  0.41364557],
#        [ 0.81539246, -0.58734842, -0.41036528, -1.31665281,  0.41364557],
#        [ 0.81539246,  1.70256694, -0.6959849 ,  0.52418188,  0.41364557],
#        ...,
#        [-1.22640329, -0.58734842, -0.47885919, -1.14620515,  0.41364557],
#        [ 0.81539246, -0.58734842,  0.34717742, -2.20298062,  0.41364557],
#        [-1.22640329, -0.58734842,  0.67389339,  0.96734579, -2.41752858]])

# %%
import joblib
joblib.dump(scaler,'ScalerLA.pkl')
# Out:
# ['ScalerLA.pkl']

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3)

# %%
 from sklearn.metrics import accuracy_score

# %%
def modelperformance(predictions):
    print('Accuracy score of model is {}'.format(accuracy_score(Y_test, predictions)))

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()

# %%
 lor.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
lor_pred=lor.predict(X_test)

# %%
modelperformance(lor_pred)
# Out:
# Accuracy score of model is 0.8709677419354839

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
knn = KNeighborsClassifier()
paramknn={'n_neighbors':[3,5,7,],
         "weights":["uniform","distance"]}
gridknn = GridSearchCV(knn,paramknn)
gridknn.fit(X_train,Y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7],
#                          'weights': ['uniform', 'distance']})

# %%
gridknn.best_params_
# Out:
# {'n_neighbors': 7, 'weights': 'uniform'}

# %%
knnpred = gridknn.predict(X_test)

# %%
modelperformance(knnpred)
# Out:
# Accuracy score of model is 0.8602150537634409

# %%
from sklearn.svm import SVC

# %%
svm = SVC(probability=True)  
pramsvc = {"C":[0.01,0.1,0.02,0.03,0.04,0.1],
          "kernel":['linear','poly','rbf']}

# %%
gridsvm = GridSearchCV(svm,pramsvc)

# %%
gridsvm.fit(X_train,Y_train)
# Out:
# GridSearchCV(estimator=SVC(probability=True),
#              param_grid={'C': [0.01, 0.1, 0.02, 0.03, 0.04, 0.1],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
pred_svc = gridsvm.predict(X_test)
modelperformance(pred_svc)
# Out:
# Accuracy score of model is 0.8709677419354839

# %%
joblib.dump(gridsvm,'loan_approval_model.pkl')
# Out:
# ['loan_approval_model.pkl']
